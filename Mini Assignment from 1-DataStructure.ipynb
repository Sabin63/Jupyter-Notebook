# Out:
# (657,
#  620,
#  631,
#  484,
#  607,
#  637,
#  638,
#  478,
#  692,
#  611,
#  576,
#  514,
#  610,
#  614,
#  622,
#  521)

# %% [markdown]
# ### Three Characters

# %%
DNA.count("AAT"),DNA.count("AAC"),DNA.count('AAG'),DNA.count('AAA'),DNA.count('ATA'),DNA.count('ATC'),DNA.count('ATG'),DNA.count('ATT'),DNA.count('ACA'),DNA.count('ACT'),DNA.count('ACG'),DNA.count('ACC'),DNA.count('AGA'),DNA.count('AGT'),DNA.count('AGC'),DNA.count('AGG')
# Out:
# (147,
#  150,
#  156,
#  116,
#  151,
#  178,
#  165,
#  152,
#  166,
#  138,
#  146,
#  157,
#  141,
#  162,
#  154,
#  167)

# %%
DNA.count("TAT"),DNA.count("TAC"),DNA.count('TAG'),DNA.count('TAA'),DNA.count('TTA'),DNA.count('TTC'),DNA.count('TTG'),DNA.count('TTT'),DNA.count('TCA'),DNA.count('TCT'),DNA.count('TCG'),DNA.count('TCC'),DNA.count('TGA'),DNA.count('TGT'),DNA.count('TGC'),DNA.count('TGG')
# Out:
# (166,
#  151,
#  150,
#  132,
#  144,
#  147,
#  154,
#  132,
#  174,
#  136,
#  146,
#  170,
#  164,
#  152,
#  140,
#  170)

# %%
DNA.count("CAT"),DNA.count("CAC"),DNA.count('CAG'),DNA.count('CAA'),DNA.count('CTA'),DNA.count('CTC'),DNA.count('CTG'),DNA.count('CTT'),DNA.count('CCA'),DNA.count('CCT'),DNA.count('CCG'),DNA.count('CCC'),DNA.count('CGA'),DNA.count('CGT'),DNA.count('CGC'),DNA.count('CGG')
# Out:
# (172,
#  156,
#  184,
#  163,
#  154,
#  131,
#  163,
#  152,
#  166,
#  165,
#  141,
#  117,
#  131,
#  126,
#  155,
#  152)

# %%
DNA.count("GAT"),DNA.count("GAC"),DNA.count('GAG'),DNA.count('GAA'),DNA.count('GTA'),DNA.count('GTC'),DNA.count('GTG'),DNA.count('GTT'),DNA.count('GCA'),DNA.count('GCT'),DNA.count('GCG'),DNA.count('GCC'),DNA.count('GGA'),DNA.count('GGT'),DNA.count('GGC'),DNA.count('GGG')
# Out:
# (164,
#  146,
#  131,
#  159,
#  147,
#  170,
#  147,
#  141,
#  173,
#  161,
#  137,
#  145,
#  167,
#  162,
#  161,
#  103)
